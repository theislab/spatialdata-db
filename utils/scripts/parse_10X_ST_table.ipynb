# %% [markdown]
# # Scrape the table of spatial transcriptomics datasets from 10X Genomics website
# The website code isn't static so we need to use Selenium
#
# `geckodriver` can be downloaded from from https://github.com/mozilla/geckodriver/releases

# %%
from selenium import webdriver
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
import pandas as pd

# Set up driver for browser
firefox_options = Options()
firefox_options.add_argument("--headless") 
s = Service("./geckodriver")  # Update the path to your GeckoDriver
driver = webdriver.Firefox(service=s, options=firefox_options)

# Get table
url = "https://www.10xgenomics.com/datasets?query=&page=2&configure%5BhitsPerPage%5D=50&configure%5BmaxValuesPerFacet%5D=1000&refinementList%5Bproduct.name%5D%5B0%5D=Spatial%20Gene%20Expression"
driver.get(url)
time.sleep(20)  # Adjust time according to network speed 
html = driver.page_source

# Parse table
soup = BeautifulSoup(html, "html.parser")
table = soup.find("table", class_="css-118cv4k")
headers = [th.get_text() for th in table.find_all("th")]

rows = driver.find_elements(By.CSS_SELECTOR, "tr.css-1mz91s4") # might have to adjust when they change it
dataset_information = []
for row in rows:
    tds = row.find_elements(By.CSS_SELECTOR, "td")
    row_data = [td.text for td in tds]
    dataset_information.append(row_data)

# Close the WebDriver
driver.quit()

# %% [markdown]
# ## Santise and convert to csv

# %%
headers = [h for h in headers if len(h) > 0]
rows_for_df = []
for row in dataset_information:
    if len(row) != 0:

        # weirdly, sometimes the 2nd element is empty
        if len(row) == len(headers) + 1 and len(row[1]) == 0:
            row.pop(1)
        assert len(row) == len(headers)
        rows_for_df.append(row)

df = pd.DataFrame(rows_for_df, columns=headers)
df
# Out:
#                                              Datasets  \
# 0   Visium CytAssist Gene Expression Libraries of ...
# 1   Visium CytAssist Gene Expression Libraries of ...
# 2   Preservation Method Comparison on Visium CytAs...
# 3   Preservation Method Comparison on Visium CytAs...
# 4   Preservation Method Comparison on Visium CytAs...
# ..                                                ...
# 83  Mouse Brain Serial Section 2 (Sagittal-Posterior)
# 84   Mouse Brain Serial Section 2 (Sagittal-Anterior)
# 85  Mouse Brain Serial Section 1 (Sagittal-Posterior)
# 86   Mouse Brain Serial Section 1 (Sagittal-Anterior)
# 87                      Mouse Brain Section (Coronal)
#
#                    Products Chemistry Version Additional Applications  \
# 0   Spatial Gene Expression                v2                     N/A
# 1   Spatial Gene Expression                v2                     N/A
# 2   Spatial Gene Expression                v2                     N/A
# 3   Spatial Gene Expression                v2                     N/A
# 4   Spatial Gene Expression                v2                     N/A
# ..                      ...               ...                     ...
# 83  Spatial Gene Expression                v1                     N/A
# 84  Spatial Gene Expression                v1                     N/A
# 85  Spatial Gene Expression                v1                     N/A
# 86  Spatial Gene Expression                v1                     N/A
# 87  Spatial Gene Expression                v1                     N/A
#
#         Software Pipeline Version        Subpipeline Species  \
# 0   Space Ranger           v2.1.0  spaceranger count   Human
# 1   Space Ranger           v2.1.0  spaceranger count   Mouse
# 2   Space Ranger           v2.1.0  spaceranger count   Mouse
# 3   Space Ranger           v2.1.0  spaceranger count   Mouse
# 4   Space Ranger           v2.1.0  spaceranger count   Mouse
# ..           ...              ...                ...     ...
# 83  Space Ranger           v1.0.0  spaceranger count   Mouse
# 84  Space Ranger           v1.0.0  spaceranger count   Mouse
# 85  Space Ranger           v1.0.0  spaceranger count   Mouse
# 86  Space Ranger           v1.0.0  spaceranger count   Mouse
# 87  Space Ranger           v1.0.0  spaceranger count   Mouse
#
#                        Disease State Anatomical entity  ...  \
# 0   cancer; adenocarcinoma stage IIA             colon  ...
# 1                                                brain  ...
# 2                            healthy             brain  ...
# 3                            healthy             brain  ...
# 4                            healthy             brain  ...
# ..                               ...               ...  ...
# 83                               N/A             brain  ...
# 84                               N/A             brain  ...
# 85                               N/A             brain  ...
# 86                               N/A             brain  ...
# 87                               N/A             brain  ...
#
#    Preservation Method Staining Method Selected Cell Types  \
# 0                 FFPE                                 N/A
# 1         Fresh Frozen                                 N/A
# 2         Fixed Frozen             H&E                 N/A
# 3         Fresh Frozen             H&E                 N/A
# 4                 FFPE             H&E                 N/A
# ..                 ...             ...                 ...
# 83        Fresh Frozen             H&E                 N/A
# 84        Fresh Frozen             H&E                 N/A
# 85        Fresh Frozen             H&E                 N/A
# 86        Fresh Frozen             H&E                 N/A
# 87        Fresh Frozen             H&E                 N/A
#
#                            Biomaterial type Cell line Feature Barcode  \
# 0   Specimen from Organism, Imaged Specimen       N/A             N/A
# 1   Specimen from Organism, Imaged Specimen       N/A             N/A
# 2   Specimen from Organism, Imaged Specimen       N/A             N/A
# 3   Specimen from Organism, Imaged Specimen       N/A             N/A
# 4   Specimen from Organism, Imaged Specimen       N/A             N/A
# ..                                      ...       ...             ...
# 83                   Specimen from Organism       N/A             N/A
# 84                   Specimen from Organism       N/A             N/A
# 85                   Specimen from Organism       N/A             N/A
# 86                   Specimen from Organism       N/A             N/A
# 87                   Specimen from Organism       N/A             N/A
#
#    Donor count Development Stage 10x Instrument(s) Publish Date
# 0            1               N/A  Visium CytAssist   2023-10-05
# 1            1               N/A  Visium CytAssist   2023-10-05
# 2          N/A               N/A  Visium CytAssist   2023-06-08
# 3          N/A               N/A  Visium CytAssist   2023-06-08
# 4          N/A               N/A  Visium CytAssist   2023-06-08
# ..         ...               ...               ...          ...
# 83           1               N/A               N/A   2019-12-02
# 84           1               N/A               N/A   2019-12-02
# 85           1               N/A               N/A   2019-12-02
# 86           1               N/A               N/A   2019-12-02
# 87           1               N/A               N/A   2019-12-02
#
# [88 rows x 22 columns]

# %%
df.to_csv("../data/10x_datasets.csv", index=False)
